# %%
import pandas as pd

# %%
data = pd.read_csv ('/content/cluster_analysis_dataset.csv')

# %%
data
# Out:
#      Feature_1  Feature_2
# 0     2.248357   1.930868
# 1     2.323844   2.761515
# 2     1.882923   1.882932
# 3     2.789606   2.383717
# 4     1.765263   2.271280
# ..         ...        ...
# 295   5.035783   0.761171
# 296   5.239490   1.166831
# 297   5.518770   0.744992
# 298   4.865063   0.510618
# 299   4.777853   1.188650
#
# [300 rows x 2 columns]

# %%
data.head()
# Out:
#    Feature_1  Feature_2
# 0   2.248357   1.930868
# 1   2.323844   2.761515
# 2   1.882923   1.882932
# 3   2.789606   2.383717
# 4   1.765263   2.271280

# %%
data.tail()
# Out:
#      Feature_1  Feature_2
# 295   5.035783   0.761171
# 296   5.239490   1.166831
# 297   5.518770   0.744992
# 298   4.865063   0.510618
# 299   4.777853   1.188650

# %%
data.sample(10)
# Out:
#      Feature_1  Feature_2
# 62    2.293429   3.095228
# 261   4.668688   1.285299
# 95    1.776743   2.428199
# 140   8.056759   8.331065
# 46    1.648973   1.836169
# 189   9.094901   7.595851
# 239   6.539440   1.559787
# 199   7.942730   8.618908
# 171   8.122483   7.746528
# 119   7.669107   8.426217

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Graph plot

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['Feature_1'],data['Feature_2'] )
plt.xlabel('Feature_1')
plt.ylabel('Feature_2')
plt.title('Scatter plot of the Features')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
from sklearn import cluster

# %%
k_means=cluster.KMeans(n_clusters=11, max_iter=100, random_state=1)

# %%
k_means
# Out:
# KMeans(max_iter=100, n_clusters=11, random_state=1)

# %%
k_means.fit(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(max_iter=100, n_clusters=11, random_state=1)

# %%
data['Cluster'] = k_means.predict(data)
data.head()
# Out:
#    Feature_1  Feature_2  Cluster
# 0   2.248357   1.930868        7
# 1   2.323844   2.761515        6
# 2   1.882923   1.882932        2
# 3   2.789606   2.383717        6
# 4   1.765263   2.271280        2

# %% [markdown]
# # The Cluster Plot using kmeans feature.

# %%
plt.scatter(data['Feature_1'],data['Feature_2'], c=data['Cluster'], cmap='winter')
plt.xlabel('Feature_1')
plt.ylabel('Feature_2')
plt.title('Scatter plot of Feature 1 and Feature 2')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>
